# %% [markdown]
# # Consumindo a API do GitHub com Python
#
# ## Introdução
#
# Neste exercício, vamos aprender como interagir com a API (Interface de Programação de Aplicações) do GitHub utilizando a linguagem Python. As APIs permitem que nossos programas se comuniquem com outros serviços e recuperem ou enviem dados de forma automatizada. O GitHub, sendo uma plataforma essencial para desenvolvedores, oferece uma API rica em informações sobre repositórios, usuários, commits e muito mais.
#
# **Objetivos:**
#
# * Entender o conceito de API e sua importância.
# * Aprender a fazer requisições HTTP utilizando a biblioteca `requests` do Python.
# * Autenticar requisições na API do GitHub (opcional, mas recomendado para limites maiores).
# * Interpretar a resposta da API no formato JSON.
# * Extrair informações relevantes dos dados recebidos.
# * Aplicar os conhecimentos em um exemplo prático: listar os repositórios de um usuário específico.
#
# ## Pré-requisitos
#
# * Conhecimento básico da linguagem Python.
# * Instalação da biblioteca `requests`. Caso não a tenha instalada, execute o seguinte comando no seu terminal:
#     ```bash
#     pip install requests
#     pip install json
#     ```
# * (Opcional) Uma conta no GitHub para gerar um token de acesso pessoal, caso queira fazer requisições autenticadas.
#
# ## Passo 1: Importando a Biblioteca `requests`
#
# O primeiro passo é importar a biblioteca `requests`, que nos permitirá fazer as requisições HTTP para a API do GitHub.

# %%
import requests
import json # Útil para visualizar a resposta formatada
import yaml

# %% [markdown]
# ## Passo 2: Definindo a URL da API
# Precisamos definir qual endpoint da API do GitHub queremos acessar. Para listar os repositórios de um usuário, a URL é:
#
# [https://api.github.com/users/](https://api.github.com/users/){username}/repos
# Substitua {username} pelo nome de usuário do GitHub que você deseja consultar. Por exemplo, para listar os meus repositórios:

# %%
username = "AleTavares" # Substitua pelo usuário desejado
url = f"https://api.github.com/users/{username}/repos"

# %% [markdown]
# **Dica:** Explore a [documentação da API do GitHub](https://docs.github.com/en/rest) para descobrir outros endpoints interessantes!

# %% [markdown]
# ## Passo 3: Fazendo a Requisição GET
# A maioria das APIs utiliza o método HTTP GET para recuperar dados. Vamos usar a função requests.get() para enviar uma requisição para a URL definida.

# %%
response = requests.get(url)

# %% [markdown]
# ## Passo 4: Verificando o Status da Resposta
# É importante verificar o status da resposta para saber se a requisição foi bem-sucedida. Um código de status 200 OK geralmente indica sucesso.

# %%
print(f"Código de Status: {response.status_code}")

if response.status_code == 200:
    print("Requisição bem-sucedida!")
else:
    print("Ocorreu um erro na requisição.")
    print(f"Detalhes: {response.text}")
# Out:
# Código de Status: 200
# Requisição bem-sucedida!

# %% [markdown]
# # Passo 5: Interpretando a Resposta JSON
# A API do GitHub geralmente retorna os dados no formato JSON (JavaScript Object Notation). A biblioteca requests já converte a resposta para um objeto Python que podemos manipular.

# %%
data = response.json()
print(json.dumps(data, indent=4)) # Imprime a resposta JSON de forma formatada para melhor visualização
# Out:
# [
#     {
#         "id": 796977200,
#         "node_id": "R_kgDOL4DoMA",
#         "name": "airflow",
#         "full_name": "AleTavares/airflow",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/airflow",
#         "description": null,
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/airflow",
#         "forks_url": "https://api.github.com/repos/AleTavares/airflow/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/airflow/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/airflow/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/airflow/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/airflow/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/airflow/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/airflow/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/airflow/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/airflow/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/airflow/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/airflow/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/airflow/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/airflow/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/airflow/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/airflow/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/airflow/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/airflow/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/airflow/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/airflow/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/airflow/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/airflow/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/airflow/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/airflow/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/airflow/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/airflow/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/airflow/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/airflow/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/airflow/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/airflow/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/airflow/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/airflow/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/airflow/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/airflow/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/airflow/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/airflow/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/airflow/deployments",
#         "created_at": "2024-05-07T01:13:03Z",
#         "updated_at": "2024-05-10T01:08:49Z",
#         "pushed_at": "2024-05-07T01:39:53Z",
#         "git_url": "git://github.com/AleTavares/airflow.git",
#         "ssh_url": "git@github.com:AleTavares/airflow.git",
#         "clone_url": "https://github.com/AleTavares/airflow.git",
#         "svn_url": "https://github.com/AleTavares/airflow",
#         "homepage": null,
#         "size": 40,
#         "stargazers_count": 1,
#         "watchers_count": 1,
#         "language": "Python",
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": {
#             "key": "apache-2.0",
#             "name": "Apache License 2.0",
#             "spdx_id": "Apache-2.0",
#             "url": "https://api.github.com/licenses/apache-2.0",
#             "node_id": "MDc6TGljZW5zZTI="
#         },
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 1,
#         "default_branch": "main"
#     },
#     {
#         "id": 786288505,
#         "node_id": "R_kgDOLt3PeQ",
#         "name": "AleTavares",
#         "full_name": "AleTavares/AleTavares",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/AleTavares",
#         "description": null,
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/AleTavares",
#         "forks_url": "https://api.github.com/repos/AleTavares/AleTavares/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/AleTavares/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/AleTavares/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/AleTavares/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/AleTavares/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/AleTavares/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/AleTavares/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/AleTavares/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/AleTavares/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/AleTavares/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/AleTavares/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/AleTavares/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/AleTavares/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/AleTavares/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/AleTavares/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/AleTavares/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/AleTavares/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/AleTavares/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/AleTavares/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/AleTavares/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/AleTavares/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/AleTavares/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/AleTavares/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/AleTavares/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/AleTavares/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/AleTavares/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/AleTavares/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/AleTavares/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/AleTavares/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/AleTavares/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/AleTavares/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/AleTavares/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/AleTavares/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/AleTavares/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/AleTavares/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/AleTavares/deployments",
#         "created_at": "2024-04-14T01:52:36Z",
#         "updated_at": "2025-04-24T23:34:57Z",
#         "pushed_at": "2024-04-14T14:45:32Z",
#         "git_url": "git://github.com/AleTavares/AleTavares.git",
#         "ssh_url": "git@github.com:AleTavares/AleTavares.git",
#         "clone_url": "https://github.com/AleTavares/AleTavares.git",
#         "svn_url": "https://github.com/AleTavares/AleTavares",
#         "homepage": null,
#         "size": 20,
#         "stargazers_count": 4,
#         "watchers_count": 4,
#         "language": null,
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": null,
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 4,
#         "default_branch": "main"
#     },
#     {
#         "id": 971122507,
#         "node_id": "R_kgDOOeInSw",
#         "name": "ambientedevADS",
#         "full_name": "AleTavares/ambientedevADS",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/ambientedevADS",
#         "description": null,
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/ambientedevADS",
#         "forks_url": "https://api.github.com/repos/AleTavares/ambientedevADS/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/ambientedevADS/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/ambientedevADS/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/ambientedevADS/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/ambientedevADS/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/ambientedevADS/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/ambientedevADS/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/ambientedevADS/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/ambientedevADS/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/ambientedevADS/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/ambientedevADS/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/ambientedevADS/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/ambientedevADS/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/ambientedevADS/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/ambientedevADS/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/ambientedevADS/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/ambientedevADS/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/ambientedevADS/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/ambientedevADS/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/ambientedevADS/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/ambientedevADS/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/ambientedevADS/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/ambientedevADS/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/ambientedevADS/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/ambientedevADS/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/ambientedevADS/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/ambientedevADS/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/ambientedevADS/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/ambientedevADS/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/ambientedevADS/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/ambientedevADS/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/ambientedevADS/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/ambientedevADS/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/ambientedevADS/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/ambientedevADS/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/ambientedevADS/deployments",
#         "created_at": "2025-04-23T03:47:51Z",
#         "updated_at": "2025-04-23T11:37:48Z",
#         "pushed_at": "2025-04-23T11:37:44Z",
#         "git_url": "git://github.com/AleTavares/ambientedevADS.git",
#         "ssh_url": "git@github.com:AleTavares/ambientedevADS.git",
#         "clone_url": "https://github.com/AleTavares/ambientedevADS.git",
#         "svn_url": "https://github.com/AleTavares/ambientedevADS",
#         "homepage": null,
#         "size": 9,
#         "stargazers_count": 0,
#         "watchers_count": 0,
#         "language": "Dockerfile",
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": null,
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 0,
#         "default_branch": "main"
#     },
#     {
#         "id": 304708731,
#         "node_id": "MDEwOlJlcG9zaXRvcnkzMDQ3MDg3MzE=",
#         "name": "analiseClientes",
#         "full_name": "AleTavares/analiseClientes",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/analiseClientes",
#         "description": "A equipe de produtos tem recebido feedbacks da equipe comercial e eles dizem que alguns clientes do setor de alimenta\u00e7\u00e3o (restaurantes, pizzarias, bares, etc.) est\u00e3o procurando solu\u00e7\u00f5es que os ajudem a entender melhor seus concorrentes. Eles gostariam de saber qual \u00e9 a faixa de pre\u00e7o praticada pelos concorrentes, como \u00e9 o fluxo de pessoas nesses locais, qual \u00e9 a popula\u00e7\u00e3o e a densidade demogr\u00e1fica dos bairros onde os concorrentes est\u00e3o, e etc.",
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/analiseClientes",
#         "forks_url": "https://api.github.com/repos/AleTavares/analiseClientes/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/analiseClientes/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/analiseClientes/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/analiseClientes/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/analiseClientes/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/analiseClientes/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/analiseClientes/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/analiseClientes/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/analiseClientes/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/analiseClientes/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/analiseClientes/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/analiseClientes/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/analiseClientes/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/analiseClientes/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/analiseClientes/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/analiseClientes/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/analiseClientes/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/analiseClientes/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/analiseClientes/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/analiseClientes/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/analiseClientes/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/analiseClientes/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/analiseClientes/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/analiseClientes/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/analiseClientes/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/analiseClientes/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/analiseClientes/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/analiseClientes/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/analiseClientes/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/analiseClientes/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/analiseClientes/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/analiseClientes/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/analiseClientes/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/analiseClientes/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/analiseClientes/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/analiseClientes/deployments",
#         "created_at": "2020-10-16T18:29:59Z",
#         "updated_at": "2020-10-16T18:30:04Z",
#         "pushed_at": "2020-10-16T18:30:02Z",
#         "git_url": "git://github.com/AleTavares/analiseClientes.git",
#         "ssh_url": "git@github.com:AleTavares/analiseClientes.git",
#         "clone_url": "https://github.com/AleTavares/analiseClientes.git",
#         "svn_url": "https://github.com/AleTavares/analiseClientes",
#         "homepage": null,
#         "size": 1,
#         "stargazers_count": 0,
#         "watchers_count": 0,
#         "language": null,
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": null,
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 0,
#         "default_branch": "main"
#     },
#     {
#         "id": 966877949,
#         "node_id": "R_kgDOOaFi_Q",
#         "name": "appFAQCursoADS",
#         "full_name": "AleTavares/appFAQCursoADS",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/appFAQCursoADS",
#         "description": "teste",
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/appFAQCursoADS",
#         "forks_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/appFAQCursoADS/deployments",
#         "created_at": "2025-04-15T15:32:16Z",
#         "updated_at": "2025-04-19T01:57:01Z",
#         "pushed_at": "2025-04-19T01:56:58Z",
#         "git_url": "git://github.com/AleTavares/appFAQCursoADS.git",
#         "ssh_url": "git@github.com:AleTavares/appFAQCursoADS.git",
#         "clone_url": "https://github.com/AleTavares/appFAQCursoADS.git",
#         "svn_url": "https://github.com/AleTavares/appFAQCursoADS",
#         "homepage": null,
#         "size": 115,
#         "stargazers_count": 0,
#         "watchers_count": 0,
#         "language": "Python",
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": {
#             "key": "apache-2.0",
#             "name": "Apache License 2.0",
#             "spdx_id": "Apache-2.0",
#             "url": "https://api.github.com/licenses/apache-2.0",
#             "node_id": "MDc6TGljZW5zZTI="
#         },
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 0,
#         "default_branch": "main"
#     },
#     {
#         "id": 878578157,
#         "node_id": "R_kgDONF4J7Q",
#         "name": "assistente_viagem",
#         "full_name": "AleTavares/assistente_viagem",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/assistente_viagem",
#         "description": null,
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/assistente_viagem",
#         "forks_url": "https://api.github.com/repos/AleTavares/assistente_viagem/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/assistente_viagem/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/assistente_viagem/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/assistente_viagem/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/assistente_viagem/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/assistente_viagem/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/assistente_viagem/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/assistente_viagem/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/assistente_viagem/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/assistente_viagem/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/assistente_viagem/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/assistente_viagem/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/assistente_viagem/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/assistente_viagem/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/assistente_viagem/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/assistente_viagem/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/assistente_viagem/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/assistente_viagem/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/assistente_viagem/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/assistente_viagem/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/assistente_viagem/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/assistente_viagem/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/assistente_viagem/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/assistente_viagem/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/assistente_viagem/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/assistente_viagem/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/assistente_viagem/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/assistente_viagem/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/assistente_viagem/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/assistente_viagem/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/assistente_viagem/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/assistente_viagem/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/assistente_viagem/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/assistente_viagem/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/assistente_viagem/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/assistente_viagem/deployments",
#         "created_at": "2024-10-25T16:44:12Z",
#         "updated_at": "2024-10-25T21:32:38Z",
#         "pushed_at": "2024-10-25T21:32:34Z",
#         "git_url": "git://github.com/AleTavares/assistente_viagem.git",
#         "ssh_url": "git@github.com:AleTavares/assistente_viagem.git",
#         "clone_url": "https://github.com/AleTavares/assistente_viagem.git",
#         "svn_url": "https://github.com/AleTavares/assistente_viagem",
#         "homepage": null,
#         "size": 28,
#         "stargazers_count": 0,
#         "watchers_count": 0,
#         "language": "HCL",
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": {
#             "key": "apache-2.0",
#             "name": "Apache License 2.0",
#             "spdx_id": "Apache-2.0",
#             "url": "https://api.github.com/licenses/apache-2.0",
#             "node_id": "MDc6TGljZW5zZTI="
#         },
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 0,
#         "default_branch": "main"
#     },
#     {
#         "id": 946058690,
#         "node_id": "R_kgDOOGO1wg",
#         "name": "AulaMicroservico",
#         "full_name": "AleTavares/AulaMicroservico",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/AulaMicroservico",
#         "description": null,
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/AulaMicroservico",
#         "forks_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/AulaMicroservico/deployments",
#         "created_at": "2025-03-10T14:45:20Z",
#         "updated_at": "2025-04-28T17:48:14Z",
#         "pushed_at": "2025-04-28T17:48:11Z",
#         "git_url": "git://github.com/AleTavares/AulaMicroservico.git",
#         "ssh_url": "git@github.com:AleTavares/AulaMicroservico.git",
#         "clone_url": "https://github.com/AleTavares/AulaMicroservico.git",
#         "svn_url": "https://github.com/AleTavares/AulaMicroservico",
#         "homepage": null,
#         "size": 82,
#         "stargazers_count": 1,
#         "watchers_count": 1,
#         "language": "Python",
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 1,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": null,
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 1,
#         "open_issues": 0,
#         "watchers": 1,
#         "default_branch": "main"
#     },
#     {
#         "id": 937649644,
#         "node_id": "R_kgDON-Nl7A",
#         "name": "AulaPythonUniFaat",
#         "full_name": "AleTavares/AulaPythonUniFaat",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/AulaPythonUniFaat",
#         "description": "Aula de Python",
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat",
#         "forks_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/AulaPythonUniFaat/git/refs{/sha}",
# ...
#         "subscribers_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/pyEstruturaSequencial/deployments",
#         "created_at": "2020-03-27T00:15:56Z",
#         "updated_at": "2020-05-01T17:59:59Z",
#         "pushed_at": "2020-05-01T17:59:57Z",
#         "git_url": "git://github.com/AleTavares/pyEstruturaSequencial.git",
#         "ssh_url": "git@github.com:AleTavares/pyEstruturaSequencial.git",
#         "clone_url": "https://github.com/AleTavares/pyEstruturaSequencial.git",
#         "svn_url": "https://github.com/AleTavares/pyEstruturaSequencial",
#         "homepage": null,
#         "size": 28,
#         "stargazers_count": 0,
#         "watchers_count": 0,
#         "language": "Python",
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": {
#             "key": "gpl-3.0",
#             "name": "GNU General Public License v3.0",
#             "spdx_id": "GPL-3.0",
#             "url": "https://api.github.com/licenses/gpl-3.0",
#             "node_id": "MDc6TGljZW5zZTk="
#         },
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 0,
#         "default_branch": "master"
#     },
#     {
#         "id": 250561738,
#         "node_id": "MDEwOlJlcG9zaXRvcnkyNTA1NjE3Mzg=",
#         "name": "pyMapas",
#         "full_name": "AleTavares/pyMapas",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/pyMapas",
#         "description": "Gr\u00e1ficos de mapas com Python utilizando utilizando a biblioteca Folium",
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/pyMapas",
#         "forks_url": "https://api.github.com/repos/AleTavares/pyMapas/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/pyMapas/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/pyMapas/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/pyMapas/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/pyMapas/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/pyMapas/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/pyMapas/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/pyMapas/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/pyMapas/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/pyMapas/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/pyMapas/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/pyMapas/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/pyMapas/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/pyMapas/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/pyMapas/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/pyMapas/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/pyMapas/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/pyMapas/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/pyMapas/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/pyMapas/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/pyMapas/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/pyMapas/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/pyMapas/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/pyMapas/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/pyMapas/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/pyMapas/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/pyMapas/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/pyMapas/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/pyMapas/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/pyMapas/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/pyMapas/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/pyMapas/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/pyMapas/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/pyMapas/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/pyMapas/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/pyMapas/deployments",
#         "created_at": "2020-03-27T14:52:41Z",
#         "updated_at": "2020-04-04T16:19:09Z",
#         "pushed_at": "2020-04-04T16:19:07Z",
#         "git_url": "git://github.com/AleTavares/pyMapas.git",
#         "ssh_url": "git@github.com:AleTavares/pyMapas.git",
#         "clone_url": "https://github.com/AleTavares/pyMapas.git",
#         "svn_url": "https://github.com/AleTavares/pyMapas",
#         "homepage": null,
#         "size": 9317,
#         "stargazers_count": 0,
#         "watchers_count": 0,
#         "language": "Jupyter Notebook",
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": null,
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 0,
#         "default_branch": "master"
#     },
#     {
#         "id": 274141885,
#         "node_id": "MDEwOlJlcG9zaXRvcnkyNzQxNDE4ODU=",
#         "name": "scrapingCovid19",
#         "full_name": "AleTavares/scrapingCovid19",
#         "private": false,
#         "owner": {
#             "login": "AleTavares",
#             "id": 26208567,
#             "node_id": "MDQ6VXNlcjI2MjA4NTY3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/26208567?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AleTavares",
#             "html_url": "https://github.com/AleTavares",
#             "followers_url": "https://api.github.com/users/AleTavares/followers",
#             "following_url": "https://api.github.com/users/AleTavares/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AleTavares/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AleTavares/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AleTavares/subscriptions",
#             "organizations_url": "https://api.github.com/users/AleTavares/orgs",
#             "repos_url": "https://api.github.com/users/AleTavares/repos",
#             "events_url": "https://api.github.com/users/AleTavares/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AleTavares/received_events",
#             "type": "User",
#             "user_view_type": "public",
#             "site_admin": false
#         },
#         "html_url": "https://github.com/AleTavares/scrapingCovid19",
#         "description": "Lab 5  Scraping de Relat\u00f3rios em PDF da OMS - Organiza\u00e7\u00e3o Mundial da Sa\u00fade  Matem\u00e1tica Para Previs\u00e3o do COVID-19",
#         "fork": false,
#         "url": "https://api.github.com/repos/AleTavares/scrapingCovid19",
#         "forks_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/forks",
#         "keys_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/keys{/key_id}",
#         "collaborators_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/collaborators{/collaborator}",
#         "teams_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/teams",
#         "hooks_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/hooks",
#         "issue_events_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/issues/events{/number}",
#         "events_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/events",
#         "assignees_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/assignees{/user}",
#         "branches_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/branches{/branch}",
#         "tags_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/tags",
#         "blobs_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/git/blobs{/sha}",
#         "git_tags_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/git/tags{/sha}",
#         "git_refs_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/git/refs{/sha}",
#         "trees_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/git/trees{/sha}",
#         "statuses_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/statuses/{sha}",
#         "languages_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/languages",
#         "stargazers_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/stargazers",
#         "contributors_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/contributors",
#         "subscribers_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/subscribers",
#         "subscription_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/subscription",
#         "commits_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/commits{/sha}",
#         "git_commits_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/git/commits{/sha}",
#         "comments_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/comments{/number}",
#         "issue_comment_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/issues/comments{/number}",
#         "contents_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/contents/{+path}",
#         "compare_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/compare/{base}...{head}",
#         "merges_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/merges",
#         "archive_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/{archive_format}{/ref}",
#         "downloads_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/downloads",
#         "issues_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/issues{/number}",
#         "pulls_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/pulls{/number}",
#         "milestones_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/milestones{/number}",
#         "notifications_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/notifications{?since,all,participating}",
#         "labels_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/labels{/name}",
#         "releases_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/releases{/id}",
#         "deployments_url": "https://api.github.com/repos/AleTavares/scrapingCovid19/deployments",
#         "created_at": "2020-06-22T13:17:12Z",
#         "updated_at": "2020-07-18T14:44:13Z",
#         "pushed_at": "2020-07-18T14:44:10Z",
#         "git_url": "git://github.com/AleTavares/scrapingCovid19.git",
#         "ssh_url": "git@github.com:AleTavares/scrapingCovid19.git",
#         "clone_url": "https://github.com/AleTavares/scrapingCovid19.git",
#         "svn_url": "https://github.com/AleTavares/scrapingCovid19",
#         "homepage": null,
#         "size": 7,
#         "stargazers_count": 0,
#         "watchers_count": 0,
#         "language": "Python",
#         "has_issues": true,
#         "has_projects": true,
#         "has_downloads": true,
#         "has_wiki": true,
#         "has_pages": false,
#         "has_discussions": false,
#         "forks_count": 0,
#         "mirror_url": null,
#         "archived": false,
#         "disabled": false,
#         "open_issues_count": 0,
#         "license": null,
#         "allow_forking": true,
#         "is_template": false,
#         "web_commit_signoff_required": false,
#         "topics": [],
#         "visibility": "public",
#         "forks": 0,
#         "open_issues": 0,
#         "watchers": 0,
#         "default_branch": "master"
#     }
# ]

# %% [markdown]
# # Passo 6: Extraindo Informações Relevantes
# Agora que temos os dados em formato Python (uma lista de dicionários, onde cada dicionário representa um repositório), podemos extrair as informações que nos interessam. Por exemplo, vamos listar o nome e a URL de cada repositório:

# %%
print(f"\nRepositórios de {username}:")
for repo in data:
    print(f"- Nome: {repo['name']}")
    print(f"  URL: {repo['html_url']}\n")
# Out:
# Repositórios de AleTavares:
# - Nome: airflow
#   URL: https://github.com/AleTavares/airflow
#
# - Nome: AleTavares
#   URL: https://github.com/AleTavares/AleTavares
#
# - Nome: ambientedevADS
#   URL: https://github.com/AleTavares/ambientedevADS
#
# - Nome: analiseClientes
#   URL: https://github.com/AleTavares/analiseClientes
#
# - Nome: appFAQCursoADS
#   URL: https://github.com/AleTavares/appFAQCursoADS
#
# - Nome: assistente_viagem
#   URL: https://github.com/AleTavares/assistente_viagem
#
# - Nome: AulaMicroservico
#   URL: https://github.com/AleTavares/AulaMicroservico
#
# - Nome: AulaPythonUniFaat
#   URL: https://github.com/AleTavares/AulaPythonUniFaat
#
# - Nome: AzureAI_analise_docs_anti_fraude
#   URL: https://github.com/AleTavares/AzureAI_analise_docs_anti_fraude
#
# - Nome: azure_openia
#   URL: https://github.com/AleTavares/azure_openia
#
# - Nome: coletaDadosIBGE
#   URL: https://github.com/AleTavares/coletaDadosIBGE
#
# - Nome: colheitaSoja
#   URL: https://github.com/AleTavares/colheitaSoja
#
# - Nome: compare-names-app
#   URL: https://github.com/AleTavares/compare-names-app
#
# - Nome: cotacaoProdutos
#   URL: https://github.com/AleTavares/cotacaoProdutos
#
# - Nome: dio-lab-open-source
#   URL: https://github.com/AleTavares/dio-lab-open-source
#
# - Nome: dockerPython
#   URL: https://github.com/AleTavares/dockerPython
#
# - Nome: dockerSpark
#   URL: https://github.com/AleTavares/dockerSpark
#
# - Nome: introductFlask
#   URL: https://github.com/AleTavares/introductFlask
#
# - Nome: josiastavares
#   URL: https://github.com/AleTavares/josiastavares
#
# - Nome: ObservabilidadeBancoDados
#   URL: https://github.com/AleTavares/ObservabilidadeBancoDados
#
# - Nome: pipelineStepFunctionGlue
#   URL: https://github.com/AleTavares/pipelineStepFunctionGlue
#
# - Nome: postgre_AWS_RDS
#   URL: https://github.com/AleTavares/postgre_AWS_RDS
#
# - Nome: prompt_personal_trening_ia
#   URL: https://github.com/AleTavares/prompt_personal_trening_ia
#
# - Nome: pyAnaliseDadosAPI
#   URL: https://github.com/AleTavares/pyAnaliseDadosAPI
#
# - Nome: pyAnaliseTexto
#   URL: https://github.com/AleTavares/pyAnaliseTexto
#
# - Nome: pyCNPJ
#   URL: https://github.com/AleTavares/pyCNPJ
#
# - Nome: pyEnriqueceDados
#   URL: https://github.com/AleTavares/pyEnriqueceDados
#
# - Nome: pyEstruturaSequencial
#   URL: https://github.com/AleTavares/pyEstruturaSequencial
#
# - Nome: pyMapas
#   URL: https://github.com/AleTavares/pyMapas
#
# - Nome: scrapingCovid19
#   URL: https://github.com/AleTavares/scrapingCovid19

# %% [markdown]
# ## Passo 7: Autenticação (Opcional)
# Para aumentar o limite de requisições que podemos fazer à API do GitHub, é recomendado usar autenticação. Você pode criar um token de acesso pessoal nas configurações da sua conta do GitHub (Settings -> Developer settings -> Personal access tokens).
#
# Para autenticar sua requisição, você pode incluir o token no cabeçalho da requisição:

# %%
# Crie um arquivo tokens.yaml com os tokens de acesso para o git ou sobistitua a variavel config['git'] pelo seu token
import requests
import yaml

with open('tokens.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)

headers = {'Authorization': config['git']}
response_authenticated = requests.get(url, headers=headers)

if response_authenticated.status_code == 200:
    data_authenticated = response_authenticated.json()
    print("\nResposta autenticada recebida com sucesso!")
    # Processar os dados autenticados aqui
else:
    print(f"\nErro na requisição autenticada: {response_authenticated.status_code}")
    print(f"Detalhes: {response_authenticated.text}")
# Out:
# Resposta autenticada recebida com sucesso!

# %% [markdown]
# **Importante:** Mencione as permissões que podem ser concedidas aos tokens e a importância de manter os tokens em segurança.

# %% [markdown]
# ## Desafios Adicionais
# - Modifique o código para listar informações diferentes dos repositórios, como a descrição, a linguagem principal ou o número de estrelas.
# - Crie um programa que permita ao usuário inserir um nome de usuário do GitHub e exiba os repositórios.
# - Explore outros endpoints da API do GitHub, como a listagem de seguidores de um usuário ou os detalhes de um commit específico.
# - Implemente tratamento de erros mais robusto para lidar com diferentes códigos de status da API.
# - Utilize paginação para lidar com casos em que um usuário possui muitos repositórios (a API do GitHub pagina as respostas).
#
# ## Conclusão
# Neste exercício, demos os primeiros passos para consumir a poderosa API do GitHub com Python. Aprender a interagir com APIs abre um mundo de possibilidades para automatizar tarefas, integrar sistemas e obter dados de diversas fontes. Continue explorando a documentação da API do GitHub e praticando para aprofundar seus conhecimentos!
